# %%
# !pip install pickle
import pickle

# %%
data = pickle.load(open("recipe_ingredient_bows.pkl", "rb"))

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(data, size=5, window=1000 * len(data), min_count=1, workers=4)
word_vectors = model.wv
X = model[model.wv.vocab]
# Out:
# <ipython-input-4-25e8d833a627>:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   X = model[model.wv.vocab]

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
pyplot.figure(figsize=(20,20))

pca = PCA(n_components=2)
result = pca.fit_transform(X)
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.xlabel('x')
pyplot.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
pyplot.figure(figsize=(20,20))
data = pickle.load(open("simple_recipe_ingredient_bows.pkl", "rb"))
simple_model = Word2Vec(data, size=5, window=1000 * len(data), min_count=1, workers=4)
word_vectors = simple_model.wv
X = simple_model[simple_model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
pyplot.scatter(result[:, 0], result[:, 1])
words = list(simple_model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.xlabel('x')
pyplot.ylabel('y')
# Out:
# <ipython-input-6-a2dd1d9c782b>:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   X = simple_model[simple_model.wv.vocab]
# Text(0, 0.5, 'y')

# %%
result2 = model.most_similar(positive=['fresh ginger', 'cinnamon stick'], negative=[], topn=50)
print(result2)
# Out:
# [('lean lamb', 0.9927546977996826), ('sunflower oil', 0.9924911260604858), ('star anise', 0.9886488318443298), ('ground aniseed', 0.9876624941825867), ('whole coriander seed', 0.987282395362854), ('yogurt', 0.9853775501251221), ('scotch bonnet pepper', 0.9848796129226685), ('fruit nectar', 0.9836604595184326), ('yellow mustard seed', 0.9835628271102905), ('coriander seed', 0.9768972992897034), ('curry paste', 0.9744113087654114), ('swordfish fillet', 0.9727524518966675), ('pork tenderloin', 0.9701572060585022), ('black mustard seed', 0.9697912931442261), ('dried red chily', 0.9688260555267334), ('red chily', 0.9684165716171265), ('sicilian olife', 0.9652978777885437), ('smooth cashew butter', 0.9651429653167725), ('moose', 0.964277982711792), ('dried shrimp paste', 0.9626611471176147), ('pumpkin seed', 0.9623904228210449), ('yoghurt', 0.9603680372238159), ('mild curry powder', 0.9593133330345154), ('basmati rice', 0.957747220993042), ('honey', 0.9547780156135559), ('tamarind pulp', 0
# ...

# %%
result2 = model.most_similar(positive=['popcorn'], negative=[], topn=50)
print(result2)
# Out:
# [('dried white pea bean', 0.996741533279419), ('fiber one cereal', 0.995646595954895), ('peanut butter frosting', 0.993255615234375), ('corn pops cereal', 0.9903744459152222), ('cereal', 0.989047646522522), ('quick oatmeal', 0.9887868165969849), ('meat piece', 0.9881341457366943), ('cinnamon-sugar mixture', 0.9880808591842651), ('dark chocolate syrup', 0.9863095283508301), ('mocha instant coffee', 0.9862743616104126), ('cranberry-orange relish', 0.9853608012199402), ('gingersnap cookie', 0.9849338531494141), ('meat marinade', 0.9835225939750671), ('raisin bran cereal', 0.9829854965209961), ('unsifted flmy', 0.9825525283813477), ('popped corn', 0.9812870025634766), ('white karo', 0.9812304973602295), ('pimiento strip', 0.981112539768219), ('chocolate whey protein powder', 0.9810802936553955), ('canned spaghetti in tomato sauce', 0.9808108806610107), ('fruit loops cereal', 0.9806933403015137), ('oatmeal squares cereal', 0.9802712798118591), ('pork stuffing mix', 0.9799289703369141), ('
# ...

# %%
result2 = simple_model.most_similar(positive=['popcorn'], negative=[], topn=50)
print(result2)
# Out:
# [('powdered nondairy creamer', 0.9717943668365479), ('cheerios', 0.9698394536972046), ('instant coffee granule', 0.9606906175613403), ('cheese nip', 0.9562438130378723), ('corn chex', 0.9469523429870605), ('rice krispy', 0.9404066205024719), ('candy', 0.9381115436553955), ('rice chex', 0.9380176067352295), ("m&m'", 0.9367976784706116), ('pretzel twist', 0.9347765445709229), ('cereal', 0.9326344728469849), ('pork top loin', 0.9320931434631348), ('coffee', 0.9302642345428467), ('coffee creamer', 0.928921639919281), ('wheat chex', 0.9288413524627686), ('almond bark', 0.9215419292449951), ('banana pulp', 0.9210665225982666), ('whey powder', 0.9206316471099854), ('cocoa powder', 0.9119561910629272), ('chip', 0.8987413644790649), ('amchur powder', 0.8953997492790222), ('marshmallow', 0.8936631679534912), ('quorn mince', 0.8902117013931274), ('espresso granule', 0.8873945474624634), ('instant mocha coffee powder', 0.8850258588790894), ('licorice', 0.8819503784179688), ('cocoa', 0.8802322149
# ...

# %%
# !pip install pickle
import pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
data = pickle.load(open("recipe_ingredient_bows.pkl", "rb"))

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(data, size=5, window=1000 * len(data), min_count=1, workers=4)
word_vectors = model.wv
X = model[model.wv.vocab]
# Out:
# C:\Users\quynh\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
pyplot.figure(figsize=(20,20))

pca = PCA(n_components=2)
result = pca.fit_transform(X)
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.xlabel('x')
pyplot.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
pyplot.savefig('food2vec.png')

# %%
result2 = model.most_similar(positive=['fresh ginger', 'cinnamon stick'], negative=[], topn=50)
print(result2)
# Out:
# [('sunflower oil', 0.9941384196281433), ('chili bean sauce', 0.9839468002319336), ('coriander seed', 0.9826875329017639), ('yellow mustard seed', 0.9825175404548645), ('chinese five spice powder', 0.9821158051490784), ('star anise', 0.9784834384918213), ('pork tenderloin', 0.9778693914413452), ('tamarus', 0.9763661623001099), ('whole black peppercorn', 0.9763105511665344), ('lamb shoulder', 0.9744470119476318), ('dried hot red chili pepper', 0.973296046257019), ('pumpkin seed', 0.9732374548912048), ('safflower oil', 0.9703179001808167), ('wood ear mushroom', 0.9677646160125732), ('lean lamb', 0.9675654768943787), ('honey', 0.967383086681366), ('malt vinegar', 0.966191291809082), ('light soya sauce', 0.9661550521850586), ('orange dried cranberry', 0.9660522937774658), ('spice mix', 0.96543288230896), ('cardamom pod', 0.9650303721427917), ('fresh gingerroot', 0.964907705783844), ('powdered allspice', 0.9640603065490723), ('basmati rice', 0.9628821611404419), ('gomashio', 0.962491154670
# ...

# %%
result2 = model.most_similar(positive=['popcorn'], negative=[], topn=10)
print(result2)
# Out:
# [('white karo', 0.9989657402038574), ('sea bream fillet', 0.9964327216148376), ('hungry jack big flaky refrigerated biscuit', 0.9953998327255249), ('caramel filled s chocolate kiss', 0.9942382574081421), ('gumdrop', 0.9934669137001038), ('corn pops cereal', 0.9930950999259949), ('golden grahams cereal', 0.9921129941940308), ('white corn syrup', 0.9916492700576782), ('ature pretzel twist', 0.9914693236351013), ('karo syrup', 0.9910016655921936), ('piece', 0.9903902411460876), ('ature peanut butter cup', 0.9898947477340698), ('butterscotch pudding mix', 0.9895370006561279), ('sweet red onion', 0.9882146716117859), ('yellow pattypan squash', 0.9871731996536255), ('light cherry pie filling', 0.987057089805603), ('coconuting', 0.9869053363800049), ('lemon frosting', 0.986767590045929), ('unsweetened dark chocolate', 0.986700177192688), ('light karo syrup', 0.986621618270874), ('ature m&m baking bit', 0.9864774942398071), ('butterscotch pudding', 0.9861656427383423), ('honey nut cheerio', 
# ...

# %%
result2 = model.most_similar(positive=['salt'], negative=[], topn=20)
print(result2)
# Out:
# [('beef bone', 0.9826180934906006), ('beef chuck', 0.9804506897926331), ('corned beef brisket', 0.9798824787139893), ('lard', 0.9793219566345215), ('dumpling', 0.9720543622970581), ('dry 18 bean soup mix', 0.9705934524536133), ('dill seed', 0.9704849720001221), ('multi-grain hot cereal', 0.9702767133712769), ('chuck steak', 0.964767336845398), ('ground savory', 0.9643385410308838), ('dried savory', 0.9641901254653931), ('stewing beef', 0.9616888761520386), ('pork loin chop', 0.9605212211608887), ('salt pork', 0.9602571725845337), ('vegetable suet', 0.9601632356643677), ('vital wheat gluten', 0.958547055721283), ('finnan haddie', 0.9579392671585083), ('dried split pea', 0.9572867751121521), ('vegetarian worcestershire sauce', 0.9565041661262512), ('caraway seed', 0.9548600316047668)]
# C:\Users\quynh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# ...

# %%
result2 = model.most_similar(positive=['fish sauce'], negative=['fish sauce'], topn=15)
print(result2)
# Out:
# [('sesame seed roll', 0.0), ('fruit slice', 0.0), ('white processed cheese', 0.0), ('smoked tofu', 0.0), ('pirouette cookies', 0.0), ('italian tomato paste', 0.0), ('frozen concentrate orange juice', 0.0), ('oreo double stuff cookies', 0.0), ('powdered chipotle pepper', 0.0), ('carbonated beverage', 0.0), ('ragu parmesan and romano spaghetti sauce', 0.0), ('dry salami', 0.0), ('sweet potatoes in syrup', 0.0), ('whole wheat hoagie roll', 0.0), ('kefalotyrus', 0.0)]
# C:\Users\quynh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

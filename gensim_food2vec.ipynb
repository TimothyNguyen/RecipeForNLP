# %%
# !pip install pickle
import pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
data = pickle.load(open("recipe_ingredient_bows.pkl", "rb"))

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(data, size=100, window=5, min_count=1, workers=4)
word_vectors = model.wv
X = model[model.wv.vocab]
# Out:
# C:\Users\quynh\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
pca = PCA(n_components=2)
result = pca.fit_transform(X)
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %%
result2 = model.most_similar(positive=['fresh ginger', 'cinnamon stick'], negative=[], topn=50)
print(result2)
# Out:
# [('fresh gingerroot', 0.8207111358642578), ('star anise', 0.815167248249054), ('gingerroot', 0.8117924332618713), ('yellow mustard seed', 0.7709330320358276), ('allspice berry', 0.7580603361129761), ('whole black peppercorn', 0.7492108345031738), ('cardamom pod', 0.7484137415885925), ('cardamom seed', 0.7430968284606934), ('coriander seed', 0.7402459383010864), ('tamarind paste', 0.7395739555358887), ('green cardamom pod', 0.7384433150291443), ('whole clove', 0.7346992492675781), ('dried red chily', 0.7222404479980469), ('whole allspice', 0.7193455696105957), ('whole coriander seed', 0.7109414935112), ('madras curry powder', 0.7011758089065552), ('minced ginger', 0.6981889605522156), ('white peppercorn', 0.6926805973052979), ('ginger', 0.692167341709137), ('powdered ginger', 0.6843993663787842), ('dried ginger', 0.6841350793838501), ('scotch bonnet pepper', 0.6777750253677368), ('orange, juice and zest of', 0.6755549907684326), ('dried red chili', 0.674343466758728), ('cinnamon bark', 0.6660465598106384), ('tamarind pulp', 0.6625744700431824), ('spice mix', 0.6617864966392517), ('whole cumin seed', 0.6605378985404968), ('ground turmeric', 0.6534411907196045), ('red chily', 0.6528679728507996), ('galangal', 0.6515978574752808), ('dried hot red chili pepper', 0.650146484375), ('fenugreek seed', 0.6475549936294556), ('basmati rice', 0.6436319351196289), ('green cardamom', 0.6433900594711304), ('red chili pepper', 0.6415318250656128), ('saffron', 0.6406025886535645), ('szechwan pepper', 0.6390092372894287), ('black mustard seed', 0.6371438503265381), ('lamb shoulder', 0.6368454694747925), ('anise seed', 0.6332663893699646), ('unsweetened coconut milk', 0.6307516098022461), ('saffron thread', 0.6303844451904297), ('lemongras', 0.6285066604614258), ('coconut milk', 0.6262639760971069), ('curry leaf', 0.625316858291626), ('powdered saffron', 0.6235336065292358), ('black peppercorn', 0.6216843128204346), ('ground ginger', 0.6206998825073242), ('black cardamom pod', 0.61980140209198)]
# C:\Users\quynh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
